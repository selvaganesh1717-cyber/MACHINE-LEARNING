# %% [markdown]
# ![](https://images.datacamp.com/image/upload/v1659712758/clustering_algorithm_8d26475260.png)

# %% [markdown]
# ## Clustering in Machine Learning
# - Clustering is an unsupervised learning technique that organizes data into groups (clusters) based on similarity or distance measures such as Euclidean distance.
# - The objective is to maximize intra-cluster similarity and minimize inter-cluster similarity.
# - It is widely used in customer segmentation, image segmentation, and anomaly detection. Popular algorithms include K-means, hierarchical clustering, and DBSCAN.
# - Purpose: Discover natural groupings in data without predefined labels.
# - Output: Groups of data points (clusters).
# - Typical Use Cases: Customer segmentation, document clustering, pattern recognition.
# ## Association in Machine Learning
# - Association, often called association rule mining, finds frequent patterns, correlations, or causal structures among a set of items in large databases.
# -  It uncovers rules such as "If A, then B," where A and B are sets of items or events. This technique is common in market basket analysis to reveal items that are frequently purchased together.
# -  Purpose: Discover interesting relationships or rules between variables.
# -  Output: Association rules with measures like support, confidence, and lift.
# -  Typical Use Cases: Market basket analysis, recommendation systems, cross-selling.

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:1400/1*4yFCbNwp0gGdGR5KbquFHA.png)

# %% [markdown]
# ![](https://cdn.analyticsvidhya.com/wp-content/uploads/2024/08/Screenshot-from-2019-08-07-16-25-31.webp)

# %% [markdown]
# ![](https://studyopedia.com/wp-content/uploads/2024/10/Clustering-vs-Association-in-Unsupervised-Learning.png)

# %% [markdown]
# # Clustering:
# - it is an unsupervised machine learning technique with a lot of applications in the areas of pattern recognition, image analysis, customer analytics, market segmentation, social network analysis, and more.
# - A broad range of industries use clustering, from airlines to healthcare and beyond.
#
# It is a type of unsupervised learning, meaning that we do not need labeled data for clustering algorithms; this is one of the biggest advantages of clustering over other supervised learning like Classification.
#
# ## What is clustering?
# Business applications/use-cases of clustering
# ### 5 essential clustering algorithms
# - K-Means
# - MeanShift
# - DBSCAN
# - Hierarchical clustering
# - BIRCH

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:786/format:webp/1*BeRECF4qxRpubZMYyCawWg.jpeg)

# %% [markdown]
# ![](https://images.datacamp.com/image/upload/v1725630538/image_9c867e067e.png)

# %% [markdown]
# # Introduction
#
# Differently from supervised learning algorithms, unsupervised learning consists into looking for undetected patterns in a dataset, with no pre-existing labels attached to each entry. Its goal is to infer properties of the probability density governing the population from which the available observations come, without the help of a supervisor/teacher providing a degree of error for each observation.
#
# **Cluster analysis**, or _data segmentation_, is a type of unsupervised learning technique, that aims at grouping collection of objects into **clusters**, such that elements within each cluster are more related (or _similar_, according to a suitable notion of similarity, which is application-dependent) to one another than objects in different clusters.  In other words, it aims at minimizing the intra-cluster distances, while maximizing inter-cluster ones.
#
# A **clustering** is a set of clusters.
#
# Note that, sometimes, the notion of cluster can be ambiguous, and different assumptions about the total number of clusters yields to different results.
#
# <img src="https://github.com/pietroventurini/machine-learning-notes/blob/main/images/cluster_analysis/n_of_clusters.jpg?raw=1" alt="Three different assumptions about the number of clusters" style="display:block; margin-left: auto; margin-right: auto; width:70em"/>
#
# We can distinguish between:
# - **Partitional clustering**: each object belongs in exactly one cluster. A famous algorithm that belongs to this family is ***k-means***.
# - **Hierarchical clustering**: consists in a set of **nested clusters** organized in a tree.
#
# Partitional clustering           |  Hierarchical clustering
# :-------------------------:|:-------------------------:
# <img src="https://github.com/pietroventurini/machine-learning-notes/blob/main/images/cluster_analysis/partitional.jpg?raw=1" alt="Partitional clustering" style="width:30em"/>  |  <img src="https://github.com/pietroventurini/machine-learning-notes/blob/main/images/cluster_analysis/hierarchical.jpg?raw=1" alt="Hierarchical clustering" style="width:30em"/>
#
# Moreover, clustering can be further distinguished into:
# - **Exclusive vs Non-exclusive**: in non-exclusive clustering, points can belong simultaneously to multiple clusters.
# - **Fuzzy vs Non-fuzzy**: in fuzzy, points belong to clusters with a weight between 0 and 1. Weights must sum to 1.
# - **Partial vs Complete**: in partial, we want only a subset of the data to be clustered.
# - **Heterogeneous vs Homogeneous**: in heterogeneous, we allow cluster of different sizes, shapes and densities.

# %% [markdown]
# # K-means
#
# K-means clustering is a method of vector quantization that aims to partition $n$ observations into $k$ clusters, where the i-_th_ observation belongs to the cluster with the nearest mean.
#
# - Initialize clusters centroids $\mu_1, \dots, \mu_k \in \mathbb{R}^n$.
# - Repeat until convergence:
#     - For every point $x^{(i)}$ set $$c^{(i)} = \arg \underset{j}{\min}{\Vert x^{(i)} - \mu_j \Vert^2}$$
#     - For every $j$ set $$\mu_j = \frac{\sum_{i=1}^{n} 1\{c^{(i)} = j\}x^{(i)}}{\sum_{i=1}^{n} 1\{c^{(i)} = j\}}$$
#
# In the algorithm, $k$ is a parameter that represents the number of clusters we want to find. The centroids $\mu_j$ represent our current guess about the position of the clusters' centers. The initialization of the centroids can happen in many ways, for instance, we can randomly choose $k$ points from our training set.
#
# A graphical illustration of how the algorithm operates is shown in the following figure (credits to Stanford University):
#
# <img src="https://github.com/pietroventurini/machine-learning-notes/blob/main/images/cluster_analysis/k_means.jpg?raw=1" alt="Three different assumptions about the number of clusters" style="display:block; margin-left: auto; margin-right: auto; width:70em"/>

# %% [markdown]
# ![](https://images.datacamp.com/image/upload/v1659712758/K_means_ff7ba142c8.png)

# %% [markdown]
# ![](https://th.bing.com/th/id/OIP.DZIa2-q-VbISb1M_tiEKnQHaH2?rs=1&pid=ImgDetMain)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*Kbl7UjTSwniiznJD.png)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*rn811Sdx91dc2qej.png)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*tnek3Ju1sQPrH8B0.png)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*hWTQpkY2VEEqNzWO.png)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*6QQTkDgiYXCYNQwT.png)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*N63pUTIFeNIE1DhQ.png)

# %% [markdown]
# ![](https://i0.wp.com/dataaspirant.com/wp-content/uploads/2020/12/15-Hierarchical-Clustering-Linkages.png?resize=609%2C659&ssl=1)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:700/0*ewhKavzFwtZ8OHuT)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:372/format:webp/0*2K1CWgPXTe6cyX9C.JPG)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:360/format:webp/0*fZvScJwtHfUKLlFn.JPG)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:348/format:webp/0*TX0DN25907BjgzIU.JPG)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:484/format:webp/0*-aY6LHQKCG9M36Dk.JPG)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:582/format:webp/0*v6NtKYc0UevoloFP.JPG)

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:612/format:webp/0*mTNwmA-i1axRVSuj.JPG)

# %% [markdown]
# ## Pros:
#
# - Easy to interpret
# - Relatively fast
# - Scalable for large data sets
# - Able to choose the positions of initial centroids in a smart way that speeds up the convergence
# Guarantees convergence

# %% [markdown]
# ### Cons:
#
# - **Number of clusters** must be pre-determined.
# - K-means algorithm is not able to guess how many clusters exist in the data.
# - Determining number of clusters may well be a challenging task.
# Can only draw linear boundaries.
# - If there is **a non-linear structure** separating groups in the data, k-means will not be a good choice.
# - Slows down as the number of samples increases because at each step, k-means algorithm accesses all data points and calculates distances. An alternative way is to use a subset of data points to update the location of centroids (i.e. sklearn.cluster.MiniBatchKMeans)
# - **Sensitive to outliers**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("https://raw.githubusercontent.com/raveendran2862/dataset/refs/heads/main/Mall_Customers.csv")

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.drop('CustomerID',axis =1,inplace = True)

# %%
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                  15                      39
# 1       1   21                  15                      81
# 2       0   20                  16                       6
# 3       0   23                  16                      77
# 4       0   31                  17                      40

# %%
df.describe()
# Out:
#            Gender         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean     0.440000   38.850000           60.560000               50.200000
# std      0.497633   13.969007           26.264721               25.823522
# min      0.000000   18.000000           15.000000                1.000000
# 25%      0.000000   28.750000           41.500000               34.750000
# 50%      0.000000   36.000000           61.500000               50.000000
# 75%      1.000000   49.000000           78.000000               73.000000
# max      1.000000   70.000000          137.000000               99.000000

# %%
sns.barplot(df["Gender"].value_counts());

# %%
df["Gender"].value_counts()
# Out:
# Gender
# 0    112
# 1     88
# Name: count, dtype: int64

# %%
df1 = df[["Age","Annual Income (k$)","Spending Score (1-100)"]]
col = df1.columns
df1
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
mn = MinMaxScaler()
df1 = mn.fit_transform(df1)
df1 = pd.DataFrame(df1,columns = col)
df1
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)
# 0    0.019231            0.000000                0.387755
# 1    0.057692            0.000000                0.816327
# 2    0.038462            0.008197                0.051020
# 3    0.096154            0.008197                0.775510
# 4    0.250000            0.016393                0.397959
# ..        ...                 ...                     ...
# 195  0.326923            0.860656                0.795918
# 196  0.519231            0.909836                0.275510
# 197  0.269231            0.909836                0.744898
# 198  0.269231            1.000000                0.173469
# 199  0.230769            1.000000                0.836735
#
# [200 rows x 3 columns]

# %%
df1.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean     0.400962            0.373443                0.502041
# std      0.268635            0.215285                0.263505
# min      0.000000            0.000000                0.000000
# 25%      0.206731            0.217213                0.344388
# 50%      0.346154            0.381148                0.500000
# 75%      0.596154            0.516393                0.734694
# max      1.000000            1.000000                1.000000

# %%
gender = df["Gender"]

# %%
data = pd.concat([gender,df1],axis = 1)
data.head()
# Out:
#    Gender       Age  Annual Income (k$)  Spending Score (1-100)
# 0       1  0.019231            0.000000                0.387755
# 1       1  0.057692            0.000000                0.816327
# 2       0  0.038462            0.008197                0.051020
# 3       0  0.096154            0.008197                0.775510
# 4       0  0.250000            0.016393                0.397959

# %%
from sklearn.cluster import KMeans
k = KMeans(n_clusters = 5,random_state = 42)
k.fit(data)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
y_pred = k.fit_predict(data)
y_pred
# Out:
# array([3, 3, 1, 2, 2, 2, 1, 2, 0, 2, 0, 2, 1, 2, 4, 3, 1, 3, 0, 2, 3, 3,
#        1, 3, 1, 3, 1, 3, 1, 2, 0, 2, 0, 3, 1, 2, 1, 2, 1, 2, 1, 3, 0, 2,
#        1, 2, 1, 2, 2, 2, 1, 3, 2, 0, 1, 0, 1, 0, 2, 0, 0, 3, 1, 1, 0, 3,
#        1, 1, 3, 2, 0, 1, 1, 1, 0, 3, 1, 3, 2, 1, 0, 3, 0, 1, 2, 0, 1, 2,
#        2, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 3, 2, 1, 0, 3, 0, 2, 1, 0, 0, 0,
#        0, 2, 1, 3, 2, 2, 1, 1, 1, 1, 3, 1, 2, 3, 2, 2, 4, 3, 0, 3, 4, 3,
#        2, 2, 4, 2, 1, 3, 4, 2, 1, 3, 2, 2, 4, 3, 0, 2, 1, 3, 4, 3, 1, 2,
#        1, 2, 4, 2, 4, 2, 1, 2, 4, 2, 0, 2, 4, 2, 1, 3, 4, 3, 4, 3, 1, 2,
#        0, 3, 0, 3, 1, 2, 4, 2, 1, 3, 1, 3, 1, 2, 1, 2, 4, 2, 1, 2, 1, 3,
#        4, 3], dtype=int32)

# %%
wcss = []
for i in range (1,11):
  kmeans = KMeans(n_clusters = i)
  kmeans.fit(data)
  wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [86.68148216035951,
#  37.27227241211878,
#  29.552857611943875,
#  22.462816167819064,
#  20.361750286984645,
#  17.835569469592375,
#  14.779128167014239,
#  12.342739770611232,
#  12.082882933503395,
#  11.245302603076507]

# %%
plt.plot(range(1,11),wcss);

# %%
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,11))

visualizer.fit(np.array(wcss).reshape(-1, 1))
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv(r"Live.csv")
df.head()
# Out:
#                           status_id status_type status_published  \
# 0  246675545449582_1649696485147474       video   4/22/2018 6:00
# 1  246675545449582_1649426988507757       photo  4/21/2018 22:45
# 2  246675545449582_1648730588577397       video   4/21/2018 6:17
# 3  246675545449582_1648576705259452       photo   4/21/2018 2:29
# 4  246675545449582_1645700502213739       photo   4/18/2018 3:22
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            529           512         262        432         92         3
# 1            150             0           0        150          0         0
# 2            227           236          57        204         21         1
# 3            111             0           0        111          0         0
# 4            213             0           0        204          9         0
#
#    num_hahas  num_sads  num_angrys  Column1  Column2  Column3  Column4
# ...

# %%
df.shape
# Out:
# (7050, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status_id         7050 non-null   object
#  1   status_type       7050 non-null   object
#  2   status_published  7050 non-null   object
#  3   num_reactions     7050 non-null   int64
#  4   num_comments      7050 non-null   int64
#  5   num_shares        7050 non-null   int64
#  6   num_likes         7050 non-null   int64
#  7   num_loves         7050 non-null   int64
#  8   num_wows          7050 non-null   int64
#  9   num_hahas         7050 non-null   int64
#  10  num_sads          7050 non-null   int64
#  11  num_angrys        7050 non-null   int64
#  12  Column1           0 non-null      float64
#  13  Column2           0 non-null      float64
#  14  Column3           0 non-null      float64
#  15  Column4           0 non-null      float64
# ...

# %%
df.columns
# Out:
# Index(['status_id', 'status_type', 'status_published', 'num_reactions',
#        'num_comments', 'num_shares', 'num_likes', 'num_loves', 'num_wows',
#        'num_hahas', 'num_sads', 'num_angrys', 'Column1', 'Column2', 'Column3',
#        'Column4'],
#       dtype='object')

# %%
df.drop(["status_id","status_published","Column1","Column2","Column3","Column4"],axis = 1,inplace = True)

# %%
df.head()
# Out:
#   status_type  num_reactions  num_comments  num_shares  num_likes  num_loves  \
# 0       video            529           512         262        432         92
# 1       photo            150             0           0        150          0
# 2       video            227           236          57        204         21
# 3       photo            111             0           0        111          0
# 4       photo            213             0           0        204          9
#
#    num_wows  num_hahas  num_sads  num_angrys
# 0         3          1         1           0
# 1         0          0         0           0
# 2         1          1         0           0
# 3         0          0         0           0
# 4         0          0         0           0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7050 entries, 0 to 7049
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status_type    7050 non-null   object
#  1   num_reactions  7050 non-null   int64
#  2   num_comments   7050 non-null   int64
#  3   num_shares     7050 non-null   int64
#  4   num_likes      7050 non-null   int64
#  5   num_loves      7050 non-null   int64
#  6   num_wows       7050 non-null   int64
#  7   num_hahas      7050 non-null   int64
#  8   num_sads       7050 non-null   int64
#  9   num_angrys     7050 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 550.9+ KB

# %%
df.isna().sum()
# Out:
# status_type      0
# num_reactions    0
# num_comments     0
# num_shares       0
# num_likes        0
# num_loves        0
# num_wows         0
# num_hahas        0
# num_sads         0
# num_angrys       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2063

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (4987, 10)

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    4987.000000   4987.000000  4987.000000  4987.000000  4987.000000
# mean      309.569080    316.201925    56.455986   288.466413    17.881893
# std       512.255183   1044.033761   153.490871   499.145306    46.541067
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%        46.000000      2.000000     0.000000    45.000000     0.000000
# 50%       134.000000     10.000000     1.000000   113.000000     1.000000
# 75%       292.000000     89.000000    16.000000   254.000000     9.000000
# max      4710.000000  20990.000000  3424.000000  4710.000000   657.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  4987.000000  4987.000000  4987.000000  4987.000000
# mean      1.756567     0.979346     0.326449     0.154602
# std      10.294329     4.674973     1.745922     0.811544
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
df.status_type.unique()
# Out:
# array(['video', 'photo', 'link', 'status'], dtype=object)

# %%
x = df.drop(["status_type"],axis = 1)
y = df["status_type"]
x.columns
# Out:
# Index(['num_reactions', 'num_comments', 'num_shares', 'num_likes', 'num_loves',
#        'num_wows', 'num_hahas', 'num_sads', 'num_angrys'],
#       dtype='object')

# %%
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# x['status_type'] = le.fit_transform(x['status_type'])
# x['status_type'].unique()

# %%
x
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0               529           512         262        432         92         3
# 1               150             0           0        150          0         0
# 2               227           236          57        204         21         1
# 3               111             0           0        111          0         0
# 4               213             0           0        204          9         0
# ...             ...           ...         ...        ...        ...       ...
# 7044             86             0           0         86          0         0
# 7045             89             0           0         89          0         0
# 7046             16             0           0         14          1         0
# 7047              2             0           0          1          1         0
# 7048            351            12          22        349          2         0
#
# ...

# %%
cols = x.columns
cols
# Out:
# Index(['num_reactions', 'num_comments', 'num_shares', 'num_likes', 'num_loves',
#        'num_wows', 'num_hahas', 'num_sads', 'num_angrys'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
mn = MinMaxScaler()
x = mn.fit_transform(x)
x
# Out:
# array([[0.11231423, 0.02439257, 0.07651869, ..., 0.00636943, 0.01960784,
#         0.        ],
#        [0.03184713, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.04819533, 0.01124345, 0.0166472 , ..., 0.00636943, 0.        ,
#         0.        ],
#        ...,
#        [0.00339703, 0.        , 0.        , ..., 0.00636943, 0.        ,
#         0.        ],
#        [0.00042463, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.07452229, 0.0005717 , 0.00642523, ..., 0.        , 0.        ,
#         0.        ]])

# %%
df_x = pd.DataFrame(x,columns = cols)
df_x
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0          0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1          0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2          0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3          0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4          0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
# ...             ...           ...         ...        ...        ...       ...
# 4982       0.018259      0.000000    0.000000   0.018259   0.000000  0.000000
# 4983       0.018896      0.000000    0.000000   0.018896   0.000000  0.000000
# 4984       0.003397      0.000000    0.000000   0.002972   0.001522  0.000000
# 4985       0.000425      0.000000    0.000000   0.000212   0.001522  0.000000
# 4986       0.074522      0.000572    0.006425   0.074098   0.003044  0.000000
#
# ...

# %%
df_x.dtypes
# Out:
# num_reactions    float64
# num_comments     float64
# num_shares       float64
# num_likes        float64
# num_loves        float64
# num_wows         float64
# num_hahas        float64
# num_sads         float64
# num_angrys       float64
# dtype: object

# %%
df_x.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    4987.000000   4987.000000  4987.000000  4987.000000  4987.000000
# mean        0.065726      0.015064     0.016488     0.061246     0.027217
# std         0.108759      0.049740     0.044828     0.105976     0.070839
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%         0.009766      0.000095     0.000000     0.009554     0.000000
# 50%         0.028450      0.000476     0.000292     0.023992     0.001522
# 75%         0.061996      0.004240     0.004673     0.053928     0.013699
# max         1.000000      1.000000     1.000000     1.000000     1.000000
#
#           num_wows    num_hahas     num_sads   num_angrys
# count  4987.000000  4987.000000  4987.000000  4987.000000
# mean      0.006319     0.006238     0.006401     0.004987
# std       0.037030     0.029777     0.034234     0.026179
# min       0.000000     0.000000     0.000000     0.000000
# ...

# %%
# sc = StandardScaler()
# scaled_data = sc.fit_transform(df)
# scaled_data

# %%
x
# Out:
# array([[0.11231423, 0.02439257, 0.07651869, ..., 0.00636943, 0.01960784,
#         0.        ],
#        [0.03184713, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.04819533, 0.01124345, 0.0166472 , ..., 0.00636943, 0.        ,
#         0.        ],
#        ...,
#        [0.00339703, 0.        , 0.        , ..., 0.00636943, 0.        ,
#         0.        ],
#        [0.00042463, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.07452229, 0.0005717 , 0.00642523, ..., 0.        , 0.        ,
#         0.        ]])

# %%
df_x1 = df_x.astype(float)
df_x1
# Out:
#       num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0          0.112314      0.024393    0.076519   0.091720   0.140030  0.010791
# 1          0.031847      0.000000    0.000000   0.031847   0.000000  0.000000
# 2          0.048195      0.011243    0.016647   0.043312   0.031963  0.003597
# 3          0.023567      0.000000    0.000000   0.023567   0.000000  0.000000
# 4          0.045223      0.000000    0.000000   0.043312   0.013699  0.000000
# ...             ...           ...         ...        ...        ...       ...
# 4982       0.018259      0.000000    0.000000   0.018259   0.000000  0.000000
# 4983       0.018896      0.000000    0.000000   0.018896   0.000000  0.000000
# 4984       0.003397      0.000000    0.000000   0.002972   0.001522  0.000000
# 4985       0.000425      0.000000    0.000000   0.000212   0.001522  0.000000
# 4986       0.074522      0.000572    0.006425   0.074098   0.003044  0.000000
#
# ...

# %%
print(df_x is None)
# Out:
# False

# %%
df_x = df_x1.dropna()
df_x.dtypes
# Out:
# num_reactions    float64
# num_comments     float64
# num_shares       float64
# num_likes        float64
# num_loves        float64
# num_wows         float64
# num_hahas        float64
# num_sads         float64
# num_angrys       float64
# dtype: object

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=2, random_state=0)

kmeans.fit(df_x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[140], line 5
#       1 from sklearn.cluster import KMeans
#       3 kmeans = KMeans(n_clusters=2, random_state=0)
# ----> 5 kmeans.fit(df_x)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1536, in KMeans.fit(self, X, y, sample_weight)
#    1533     print("Initialization complete")
#    1535 # run a k-means once
# -> 1536 labels, inertia, centers, n_iter_ = kmeans_single(
#    1537     X,
# ...

# %%
kmeans.cluster_centers_

# %% [markdown]
# ### Inertia
# - Inertia is not a normalized metric.
#
# - The lower values of inertia are better and zero is optimal.
#
# - But in very high-dimensional spaces, euclidean distances tend to become inflated (this is an instance of curse of dimensionality).
#
# - Running a dimensionality reduction algorithm such as PCA prior to k-means clustering can alleviate this problem and speed up the computations.

# %%
kmeans.inertia_

# %%
labels = kmeans.labels_
labels

# %%
correct_labels = sum(y == labels)

print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))

# %%
inertia = []
for i in range(1,10):
    kmeans = KMeans(n_clusters = i,random_state = 42)
    kmeans.fit(x)
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(1,10), inertia, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_scores = []
K = range(2, 10)  # Silhouette score is not defined for k=1

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(x)
    score = silhouette_score(x, labels)
    silhouette_scores.append(score)
    print(f"Silhouette Score for k={k}: {score:.3f}")

# Plot silhouette scores
plt.figure(figsize=(8, 4))
plt.plot(K, silhouette_scores, 'o-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs Number of Clusters')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)

kmeans.fit(x)

clusters = kmeans.predict(x)
# check how many of the samples were correctly labeled
labels = kmeans.labels_

correct_labels = sum(y == labels)
print("Result: %d out of %d samples were correctly labeled." % (correct_labels, y.size))

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
principal_components = pca.fit_transform(x)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(principal_components[:, 0], principal_components[:, 1],
            c=clusters, cmap='viridis', edgecolor='k', s=50)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Cluster Visualization (2D PCA Projection)')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# ![](https://gaussian37.github.io/assets/img/ml/concept/serrano_pca/0.png)

# %% [markdown]
# ### Principal Component Analysis (PCA):
# - Principal Component Analysis (PCA) is a dimensionality reduction technique widely used in data preprocessing and analysis. It transforms high-dimensional data into a lower-dimensional space while retaining as much variability (information) as possible.
#
# ### Why Use PCA?
# - Dimensionality Reduction: Reduces the number of features while minimizing information loss.
# - Visualization: Helps visualize high-dimensional data in 2D or 3D.
# - Improves Model Performance: Reduces noise and redundancy, which can lead to better machine learning results.
# - Speeds Up Computation: Fewer dimensions mean faster processing and less storage.

# %%
[1,2  [6,7
 3,4]  8,9]

# %%
x.shape

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(x)
scaled_data

# %%
kmeans = KMeans(n_clusters=5, random_state=42, n_init=10)
clusters = kmeans.fit_predict(scaled_data)
clusters

# %%
x_copy = pd.DataFrame(x)
x_copy

# %%
x_copy["cluster "] = clusters

# %%
x_copy.sample(7)

# %%
x_copy = x_copy.select_dtypes(include =  "float64").astype("int")

# %%
x_copy.info()

# %%
# Reduce dimensions to 2 using PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(x_copy)

pca_data = pd.DataFrame(pca_data,columns = [['PCA1','PCA2']])
pca_data

# %%
pca_data["Cluster"] = kmeans.labels_

# %%
pca_data

# %%
x = pca_data.drop(["Cluster"],axis = 1)
y = pca_data["Cluster"].values.ravel()
x

# %%
print(pca_data.iloc[:, 0].shape)  # Should be (4987,)

# %%
pca_data

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    x="PCA1",
    y="PCA2",
    hue="Cluster",
    data=pca_data,
    palette="viridis",
    s=100
)

# Plot centroids
plt.scatter(
    cluster_centers_pca[:, 0],
    cluster_centers_pca[:, 1],
    marker="X", s=200, c="red", label="Centroids"
)

plt.title("K-Means Clustering (PCA Projection)")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))

# Scatter plot of clusters
sns.scatterplot(x="PCA1", y="PCA2", hue="Cluster", data=x1, palette="viridis", s=100)

# Transform cluster centers to PCA space
cluster_centers_pca = pca.transform(kmeans.cluster_centers_)

# Plot centroids
plt.scatter(cluster_centers_pca[:, 0], cluster_centers_pca[:, 1], marker="X", s=200, c="red", label="Centroids")

plt.title("K-Means Clustering (PCA Projection)")
plt.legend()
plt.show()

# %% [markdown]
# ![](https://miro.medium.com/v2/resize:fit:640/format:webp/0*xbO9q8yc4E3lujlT.JPG)

# %%
plt.scatter(x_reduced[y_predict == 0, 0], x_reduced[y_predict == 0, 1], s=100, c='red', label='Cluster 1')
plt.scatter(x_reduced[y_predict == 1, 0], x_reduced[y_predict == 1, 1], s=100, c='blue', label='Cluster 2');
plt.scatter(x_reduced[y_predict == 2, 0], x_reduced[y_predict == 2, 1], s=100, c='green', label='Cluster 3');

# %% [markdown]
# ![](https://editor.analyticsvidhya.com/uploads/62725cluster0.PNG)

# %%
plt.figure(figsize=(8, 6))

# Scatter plot for reduced dimensions
for cluster in np.unique(labels):
    cluster_points = x_reduced[labels == cluster]
    plt.scatter(
        cluster_points[:, 0],  # PCA Component 1
        cluster_points[:, 1],  # PCA Component 2
        label=f"Cluster {cluster}"
    )

# Plot centroids
centroids_reduced = pca.transform(kmeans.cluster_centers_)
plt.scatter(centroids_reduced[:, 0], centroids_reduced[:, 1], s=200, c='red', label='Centroids', marker='X')

# Labels and legend
plt.title('Scatter Plot with KMeans Clusters (PCA Reduced)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Inertia¶
# - Inertia is not a normalized metric.
#
# - The lower values of inertia are better and zero is optimal.
#
# - But in very high-dimensional spaces, euclidean distances tend to become inflated (this is an instance of curse of dimensionality).
#
# - Running a dimensionality reduction algorithm such as PCA prior to k-means clustering can alleviate this problem and speed up the computations.
